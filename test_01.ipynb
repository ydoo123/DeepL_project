# %%
# %ls
# Out:
# __pycache__/      model.py*         run.py*           test_images/
# checkpoints/      requirements.txt  test.py*          train.py*
# data/             result.txt*       test_01.ipynb*    utils/

# %%
# !python train.py --mps
# Out:
# ...
# Save path: checkpoints/
# Using Device: mps:0
# Number of usable GPUs: 0
# Batch_size: 64
# learning_rate: 0.075
# Epochs: 100
# ...
# Files already downloaded and verified
# Files already downloaded and verified
# [Epoch 1 / 100]
# 100%|█████████████████████████████████████████| 782/782 [03:30<00:00,  3.72it/s]
# Epoch 1
# train_loss: inf, val_loss: 2.1655331440032666
# train_accuracy: 20.638%, val_accuracy: 25.640%
# inf 2.1655331440032666 20.638 25.640
# [Epoch 2 / 100]
# 100%|█████████████████████████████████████████| 782/782 [03:29<00:00,  3.73it/s]
# Epoch 2
# train_loss: 1.492417141452165, val_loss: inf
# train_accuracy: 43.550%, val_accuracy: 46.960%
# 1.492417141452165 inf 43.550 46.960
# [Epoch 3 / 100]
# 100%|█████████████████████████████████████████| 782/782 [03:29<00:00,  3.73it/s]
# Epoch 3
# train_loss: 1.2097734288333932, val_loss: 1.7772606512543503
# train_accuracy: 56.494%, val_accuracy: 48.430%
# 1.2097734288333932 1.7772606512543503 56.494 48.430
# [Epoch 4 / 100]
# ...

# %%
# %ls
# Out:
# __pycache__/      model.py*         run.py*           test_images/
# checkpoints/      requirements.txt  test.py*          train.py*
# data/             result.txt*       test_01.ipynb*    utils/

# %%
import os
import sys

CURRENT_PATH = os.getcwd()
model_path = os.path.join(CURRENT_PATH, 'checkpoints/model.pth')

file_size = os.path.getsize(model_path)
mb_size = file_size / (1024 * 1024)
print('File Size:', mb_size, 'mb')
# Out:
# File Size: 12.395916938781738 mb

# %%
# !python test.py --mps
# Out:
# Files already downloaded and verified
# Files already downloaded and verified
# 100%|██████████████████████████████████████| 1250/1250 [00:10<00:00, 116.61it/s]
# Test Accuracy : 0.71590

# %%
# !python run.py
# Out:
# 100% 7/7 [00:01<00:00,  3.67it/s]
