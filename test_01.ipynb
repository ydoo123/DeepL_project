# %%
# %ls
# Out:
# checkpoints/      requirements.txt  test.py*          train.py*
# data/             result.txt*       test_01.ipynb*    utils/
# model.py*         run.py*           test_images/

# %%
# !python train.py --mps
# Out:
# ==============================
# Save path: checkpoints/
# Using Device: cpu
# Number of usable GPUs: 0
# Batch_size: 256
# learning_rate: 0.075
# Epochs: 100
# ==============================
# Files already downloaded and verified
# Files already downloaded and verified
# [Epoch 1 / 100]
#   1%|▍                                        | 2/196 [00:41<1:07:45, 20.95s/it]^C
#   1%|▍                                        | 2/196 [00:43<1:10:40, 21.86s/it]
# Traceback (most recent call last):
#   File "train.py", line 147, in <module>
#     train(args, train_loader, val_loader, model)
#   File "train.py", line 64, in train
#     output = model(image)
#   File "/Users/itaehun/miniforge3/envs/deepL/lib/python3.8/site-packages/torch/nn/modules/module.py", line 1194, in _call_impl
#     return forward_call(*input, **kwargs)
#   File "/Users/itaehun/DeepL_project/model.py", line 48, in forward
#     out = self.layers(out)
#   File "/Users/itaehun/miniforge3/envs/deepL/lib/python3.8/site-packages/torch/nn/modules/module.py", line 1194, in _call_impl
#     return forward_call(*input, **kwargs)
#   File "/Users/itaehun/miniforge3/envs/deepL/lib/python3.8/site-packages/torch/nn/modules/container.py", line 204, in forward
#     input = module(input)
#   File "/Users/itaehun/miniforge3/envs/deepL/lib/python3.8/site-packages/torch/nn/modules/module.py", line 1194, in _call_impl
#     return forward_call(*input, **kwargs)
#   File "/Users/itaehun/DeepL_project/model.py", line 22, in forward
#     out = F.relu(self.bn2(self.conv2(out)))
#   File "/Users/itaehun/miniforge3/envs/deepL/lib/python3.8/site-packages/torch/nn/modules/module.py", line 1194, in _call_impl
#     return forward_call(*input, **kwargs)
#   File "/Users/itaehun/miniforge3/envs/deepL/lib/python3.8/site-packages/torch/nn/modules/conv.py", line 463, in forward
#     return self._conv_forward(input, self.weight, self.bias)
#   File "/Users/itaehun/miniforge3/envs/deepL/lib/python3.8/site-packages/torch/nn/modules/conv.py", line 459, in _conv_forward
#     return F.conv2d(input, weight, bias, self.stride,
# KeyboardInterrupt

# %%
# %ls

# %%
import os
import sys

CURRENT_PATH = os.getcwd()
model_path = os.path.join(CURRENT_PATH, 'checkpoints/model.pth')

file_size = os.path.getsize(model_path)
mb_size = file_size / (1024 * 1024)
print('File Size:', mb_size, 'mb')
# Out:
# File Size: 12.395916938781738 mb

# %%
# !python test.py

# %%
# !python run.py
# Out:
# 100% 7/7 [00:01<00:00,  3.67it/s]
